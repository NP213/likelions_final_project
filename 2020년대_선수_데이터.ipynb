# %%
import pandas as pd

# 1. 파일 불러오기
pit_df = pd.read_csv('kbo_pitching_stats_by_season_1982-2025.csv')
bat_df = pd.read_csv('kbo_batting_stats_by_season_1982-2025.csv')

# 2. 연도 필터링 (2020년 ~ 2025년)
years = range(2020, 2026)
pit_f = pit_df[pit_df['Year'].isin(years)].copy()
bat_f = bat_df[bat_df['Year'].isin(years)].copy()

# 3. 요청하신 특정 컬럼 선택
# 투수 컬럼 (17개)
pit_cols = ['Name', 'Year', 'Team', 'G', 'GS', 'GR', 'GF', 'W', 'L', 'S', 'HD', 'IP', 'SO', 'ERA', 'FIP', 'WHIP', 'WAR']
# 타자 컬럼 (16개)
bat_cols = ['Name', 'Year', 'Team', 'Pos.', 'G', 'oWAR', 'dWAR', 'PA', 'R', 'HR', 'RBI', 'SB', 'BB', 'SO', 'AVG', 'OBP', 'SLG', 'OPS', 'wRC+', 'WAR']

pit_selected = pit_f[pit_cols]
bat_selected = bat_f[bat_cols]

# 4. 팀별로 분류하여 저장 (투수가 위, 타자가 아래)
teams = pit_selected['Team'].unique()

for team in teams:
    # 해당 팀의 데이터 추출
    team_pit = pit_selected[pit_selected['Team'] == team]
    team_bat = bat_selected[bat_selected['Team'] == team]
    
    # 투수와 타자 사이에 빈 줄을 넣거나 구분하기 어렵다면 별도로 합침
    # 컬럼 구조가 다르므로 공통 파일보다는 각 팀별 폴더나 접미사를 활용하는 것이 좋습니다.
    team_pit.to_csv(f'{team}_2020_2025_투수.csv', index=False, encoding='utf-8-sig')
    team_bat.to_csv(f'{team}_2020_2025_타자.csv', index=False, encoding='utf-8-sig')

print(f"총 {len(teams)}개 팀의 투수/타자 데이터 분류 및 저장이 완료되었습니다.")
# Out:
# 총 11개 팀의 투수/타자 데이터 분류 및 저장이 완료되었습니다.

# %%
import pandas as pd

# 1. 파일 불러오기
pit_df = pd.read_csv('kbo_pitching_stats_by_season_1982-2025.csv')
bat_df = pd.read_csv('kbo_batting_stats_by_season_1982-2025.csv')

# 2. 연도 필터링 (2020년 ~ 2025년)
years = range(2020, 2026)
pit_f = pit_df[pit_df['Year'].isin(years)].copy()
bat_f = bat_df[bat_df['Year'].isin(years)].copy()

# 3. 요청하신 특정 컬럼 선택
pit_cols = ['Name', 'Year', 'Team', 'G', 'GS', 'GR', 'GF', 'W', 'L', 'S', 'HD', 'IP', 'SO', 'ERA', 'FIP', 'WHIP', 'WAR']
bat_cols = ['Name', 'Year', 'Team', 'Pos.', 'G', 'oWAR', 'dWAR', 'PA', 'R', 'HR', 'RBI', 'SB', 'BB', 'SO', 'AVG', 'OBP', 'SLG', 'OPS', 'wRC+', 'WAR']

pit_selected = pit_f[pit_cols].copy()
bat_selected = bat_f[bat_cols].copy()

# 4. 팀명 통합 (SK -> SSG) - 요청하신 위치로 이동
pit_selected['Team'] = pit_selected['Team'].replace('SK', 'SSG')
bat_selected['Team'] = bat_selected['Team'].replace('SK', 'SSG')

# 5. 팀별 파일 저장 및 통합 확인
teams = pit_selected['Team'].unique()

for team in teams:
    # 해당 팀 데이터 추출
    team_pit = pit_selected[pit_selected['Team'] == team]
    team_bat = bat_selected[bat_selected['Team'] == team]
    
    # 투수가 위(상단), 타자가 아래(하단)로 오도록 합치기
    # 컬럼명이 다르므로 수직으로 합치면 각자 없는 컬럼은 NaN(빈값)으로 처리됩니다.
    combined = pd.concat([team_pit, team_bat], axis=0, ignore_index=True)
    
    # 저장
    combined.to_csv(f'{team}_2020_2025_통합본.csv', index=False, encoding='utf-8-sig')

print(f"✅ 총 {len(teams)}개 팀의 통합본 생성이 완료되었습니다.")
print(f"   (SK 데이터는 SSG 파일 안에 2020년 기록으로 포함되어 있습니다.)")
# Out:
# ✅ 총 10개 팀의 통합본 생성이 완료되었습니다.
#    (SK 데이터는 SSG 파일 안에 2020년 기록으로 포함되어 있습니다.)

# %%
import pandas as pd

# 1. 파일 불러오기
pit_df = pd.read_csv('kbo_pitching_stats_by_season_1982-2025.csv')
bat_df = pd.read_csv('kbo_batting_stats_by_season_1982-2025.csv')

# 2. 연도 필터링 (2020년 ~ 2025년)
years = range(2020, 2026)
pit_f = pit_df[pit_df['Year'].isin(years)].copy()
bat_f = bat_df[bat_df['Year'].isin(years)].copy()

# 3. 요청하신 특정 컬럼 선택
pit_cols = ['Name', 'Year', 'Team', 'G', 'GS', 'GR', 'GF', 'W', 'L', 'S', 'HD', 'IP', 'SO', 'ERA', 'FIP', 'WHIP', 'WAR']
bat_cols = ['Name', 'Year', 'Team', 'Pos.', 'G', 'oWAR', 'dWAR', 'PA', 'R', 'HR', 'RBI', 'SB', 'BB', 'SO', 'AVG', 'OBP', 'SLG', 'OPS', 'wRC+', 'WAR']

pit_selected = pit_f[pit_cols].copy()
bat_selected = bat_f[bat_cols].copy()

# 4. 팀명 통합 (SK -> SSG)
pit_selected['Team'] = pit_selected['Team'].replace('SK', 'SSG')
bat_selected['Team'] = bat_selected['Team'].replace('SK', 'SSG')

# 5. 팀별 분류, 정렬 및 저장
# 전체 팀 리스트 추출
teams = pit_selected['Team'].unique()

for team in teams:
    # 해당 팀 데이터 추출
    team_pit = pit_selected[pit_selected['Team'] == team].copy()
    team_bat = bat_selected[bat_selected['Team'] == team].copy()
    
    # [정렬 로직 추가] 연도순(오름차순), 연도가 같으면 WAR순(내림차순)
    team_pit = team_pit.sort_values(by=['Year', 'WAR'], ascending=[True, False])
    team_bat = team_bat.sort_values(by=['Year', 'WAR'], ascending=[True, False])
    
    # 투수 상단, 타자 하단으로 합치기
    combined = pd.concat([team_pit, team_bat], axis=0, ignore_index=True)
    
    # 파일 저장
    combined.to_csv(f'{team}_2020_2025_통합본.csv', index=False, encoding='utf-8-sig')

print("✅ 모든 팀의 데이터가 '연도순 > WAR순'으로 정렬되어 저장되었습니다.")
# Out:
# ✅ 모든 팀의 데이터가 '연도순 > WAR순'으로 정렬되어 저장되었습니다.

# %%
import pandas as pd

# 1. 파일 불러오기
pit_df = pd.read_csv('kbo_pitching_stats_by_season_1982-2025.csv')
bat_df = pd.read_csv('kbo_batting_stats_by_season_1982-2025.csv')

# 2. 연도 필터링 (2020년 ~ 2025년)
years = range(2020, 2026)
pit_f = pit_df[pit_df['Year'].isin(years)].copy()
bat_f = bat_df[bat_df['Year'].isin(years)].copy()

# 3. 요청하신 특정 컬럼 선택
pit_cols = ['Name', 'Year', 'Team', 'G', 'GS', 'GR', 'GF', 'W', 'L', 'S', 'HD', 'IP', 'SO', 'ERA', 'FIP', 'WHIP', 'WAR']
bat_cols = ['Name', 'Year', 'Team', 'Pos.', 'G', 'oWAR', 'dWAR', 'PA', 'R', 'HR', 'RBI', 'SB', 'BB', 'SO', 'AVG', 'OBP', 'SLG', 'OPS', 'wRC+', 'WAR']

pit_selected = pit_f[pit_cols].copy()
bat_selected = bat_f[bat_cols].copy()

# 4. 팀명 통합 (SK -> SSG)
pit_selected['Team'] = pit_selected['Team'].replace('SK', 'SSG')
bat_selected['Team'] = bat_selected['Team'].replace('SK', 'SSG')

# 5. [정렬] 전체 데이터를 미리 연도순(asc), WAR순(desc)으로 정렬
pit_selected = pit_selected.sort_values(by=['Year', 'WAR'], ascending=[True, False])
bat_selected = bat_selected.sort_values(by=['Year', 'WAR'], ascending=[True, False])

# 6. 팀별 분류 및 저장
teams = pit_selected['Team'].unique()

for team in teams:
    # 해당 팀 데이터 추출 (이미 정렬된 상태에서 추출됨)
    team_pit = pit_selected[pit_selected['Team'] == team]
    team_bat = bat_selected[bat_selected['Team'] == team]
    
    # (1) 개별 파일 저장 (투수/타자 각각)
    team_pit.to_csv(f'{team}_2020_2025_투수.csv', index=False, encoding='utf-8-sig')
    team_bat.to_csv(f'{team}_2020_2025_타자.csv', index=False, encoding='utf-8-sig')
    
    # (2) 통합본 파일 저장 (투수 상단, 타자 하단)
    combined = pd.concat([team_pit, team_bat], axis=0, ignore_index=True)
    combined.to_csv(f'{team}_2020_2025_통합본.csv', index=False, encoding='utf-8-sig')

print("✅ 모든 파일(투수, 타자, 통합본)이 연도순 및 WAR순으로 정렬되어 생성되었습니다.")
# Out:
# ✅ 모든 파일(투수, 타자, 통합본)이 연도순 및 WAR순으로 정렬되어 생성되었습니다.

# %%
import pandas as pd

# 1. 파일 불러오기
try:
    pit_df = pd.read_csv('kbo_pitching_stats_by_season_1982-2025.csv')
    bat_df = pd.read_csv('kbo_batting_stats_by_season_1982-2025.csv')
except FileNotFoundError:
    print("CSV 파일을 찾을 수 없습니다. 파일명을 확인해주세요.")
    exit()

# 2. 연도 필터링 (2020년 ~ 2025년)
years = range(2020, 2026)
pit_f = pit_df[pit_df['Year'].isin(years)].copy()
bat_f = bat_df[bat_df['Year'].isin(years)].copy()

# 3. 특정 컬럼 선택
pit_cols = [
    'Name', 'Year', 'Team', 'G', 'GS', 'GR', 'GF', 
    'W', 'L', 'S', 'HD', 'IP', 'SO', 'ERA', 'FIP', 'WHIP', 'WAR'
]

bat_cols = [
    'Name', 'Year', 'Team', 'Pos.', 'G', 'PA', 'H', 'R', 'HR', 'RBI', 
    'SB', 'BB', 'SO', 'AVG', 'OBP', 'SLG', 'OPS', 'wRC+', 'oWAR', 'dWAR', 'WAR'
]

pit_selected = pit_f[pit_cols].copy()
bat_selected = bat_f[bat_cols].copy()

# 4. 팀명 통합 (SK -> SSG)
pit_selected['Team'] = pit_selected['Team'].replace('SK', 'SSG')
bat_selected['Team'] = bat_selected['Team'].replace('SK', 'SSG')

# 5. 정렬 (연도 오름차순, 동일 연도 내 WAR 내림차순)
pit_selected = pit_selected.sort_values(by=['Year', 'WAR'], ascending=[True, False])
bat_selected = bat_selected.sort_values(by=['Year', 'WAR'], ascending=[True, False])

# 6. 팀별 분류 및 저장
teams = pit_selected['Team'].unique()

for team in teams:
    # 해당 팀 데이터 추출
    team_pit = pit_selected[pit_selected['Team'] == team]
    team_bat = bat_selected[bat_selected['Team'] == team]
    
    # (1) 개별 파일 저장 (투수/타자)
    team_pit.to_csv(f'{team}_2020_2025_투수.csv', index=False, encoding='utf-8-sig')
    team_bat.to_csv(f'{team}_2020_2025_타자.csv', index=False, encoding='utf-8-sig')
    
    # (2) 통합본 저장 (투수 상단, 타자 하단)
    combined = pd.concat([team_pit, team_bat], axis=0, ignore_index=True)
    combined.to_csv(f'{team}_2020_2025_통합본.csv', index=False, encoding='utf-8-sig')

print(f"✅ 총 {len(teams)}개 팀의 데이터 처리가 완료되었습니다.")
# Out:
# ✅ 총 10개 팀의 데이터 처리가 완료되었습니다.

# %%
import pandas as pd

# 1. 파일 불러오기
try:
    pit_df = pd.read_csv('kbo_pitching_stats_by_season_1982-2025.csv')
    bat_df = pd.read_csv('kbo_batting_stats_by_season_1982-2025.csv')
except FileNotFoundError:
    print("CSV 파일을 찾을 수 없습니다. 파일명을 확인해주세요.")
    exit()

# 2. 연도 필터링 (2020년 ~ 2025년)
years = range(2020, 2026)
pit_f = pit_df[pit_df['Year'].isin(years)].copy()
bat_f = bat_df[bat_df['Year'].isin(years)].copy()

# 3. 요청하신 순서대로 컬럼 재배치
# 투수: Year, Team, Name, G, GS, GR, GF, IP, W, L, S, HD, SO, ERA, FIP, WHIP, WAR
pit_cols = [
    'Year', 'Team', 'Name', 'G', 'GS', 'GR', 'GF', 
    'IP', 'W', 'L', 'S', 'HD', 'SO', 'ERA', 'FIP', 'WHIP', 'WAR'
]

# 타자: Year, Team, Name, G, PA, H, HR, RBI, R, SB, BB, SO, AVG, OBP, SLG, OPS, wRC+, oWAR, dWAR, WAR
bat_cols = [
    'Year', 'Team', 'Name', 'G', 'PA', 'H', 'HR', 'RBI', 'R', 'SB', 
    'BB', 'SO', 'AVG', 'OBP', 'SLG', 'OPS', 'wRC+', 'oWAR', 'dWAR', 'WAR'
]

pit_selected = pit_f[pit_cols].copy()
bat_selected = bat_f[bat_cols].copy()

# 4. 팀명 통합 (SK -> SSG)
pit_selected['Team'] = pit_selected['Team'].replace('SK', 'SSG')
bat_selected['Team'] = bat_selected['Team'].replace('SK', 'SSG')

# 5. 데이터 정렬 (연도 오름차순, 동일 연도 내 WAR 내림차순)
pit_selected = pit_selected.sort_values(by=['Year', 'WAR'], ascending=[True, False])
bat_selected = bat_selected.sort_values(by=['Year', 'WAR'], ascending=[True, False])

# 6. 팀별 분류 및 저장
teams = pit_selected['Team'].unique()

for team in teams:
    team_pit = pit_selected[pit_selected['Team'] == team]
    team_bat = bat_selected[bat_selected['Team'] == team]
    
    # (1) 개별 파일 저장 (투수/타자)
    team_pit.to_csv(f'{team}_2020_2025_투수.csv', index=False, encoding='utf-8-sig')
    team_bat.to_csv(f'{team}_2020_2025_타자.csv', index=False, encoding='utf-8-sig')
    
    # (2) 통합본 저장 (투수 상단, 타자 하단)
    combined = pd.concat([team_pit, team_bat], axis=0, ignore_index=True)
    combined.to_csv(f'{team}_2020_2025_통합본.csv', index=False, encoding='utf-8-sig')

print(f"✅ 모든 데이터가 요청하신 컬럼 순서로 정렬되어 저장되었습니다.")
# Out:
# ✅ 모든 데이터가 요청하신 컬럼 순서로 정렬되어 저장되었습니다.

# %%
import pandas as pd

# 1. 파일 불러오기
try:
    pit_df = pd.read_csv('kbo_pitching_stats_by_season_1982-2025.csv')
    bat_df = pd.read_csv('kbo_batting_stats_by_season_1982-2025.csv')
except FileNotFoundError:
    print("CSV 파일을 찾을 수 없습니다.")
    exit()

# 2. 연도 필터링 (2020~2025)
years = range(2020, 2026)
pit_f = pit_df[pit_df['Year'].isin(years)].copy()
bat_f = bat_df[bat_df['Year'].isin(years)].copy()

# 3. 요청하신 컬럼 순서 설정
pit_cols = ['Year', 'Team', 'Name', 'G', 'GS', 'GR', 'GF', 'IP', 'W', 'L', 'S', 'HD', 'SO', 'ERA', 'FIP', 'WHIP', 'WAR']
bat_cols = ['Year', 'Team', 'Name', 'G', 'PA', 'H', 'HR', 'RBI', 'R', 'SB', 'BB', 'SO', 'AVG', 'OBP', 'SLG', 'OPS', 'wRC+', 'oWAR', 'dWAR', 'WAR']

pit_selected = pit_f[pit_cols].copy()
bat_selected = bat_f[bat_cols].copy()

# 4. 팀명 통합 (SK -> SSG)
pit_selected['Team'] = pit_selected['Team'].replace('SK', 'SSG')
bat_selected['Team'] = bat_selected['Team'].replace('SK', 'SSG')

# 5. [팀 순서 지정] 요청하신 순서대로 리스트 생성
team_order = ['LG', '한화', 'SSG', '삼성', 'NC', 'KT', '롯데', 'KIA', '두산', '키움']

# 6. 정렬 및 저장
# 팀 순서대로 반복문을 실행하여 파일을 생성합니다.
for team in team_order:
    # 해당 팀 데이터 추출
    team_pit = pit_selected[pit_selected['Team'] == team].copy()
    team_bat = bat_selected[bat_selected['Team'] == team].copy()
    
    # 만약 해당 팀 데이터가 없으면 건너뜁니다 (예: 오타 방지)
    if team_pit.empty and team_bat.empty:
        continue

    # 데이터 정렬: 연도순(오름차순) -> WAR순(내림차순)
    team_pit = team_pit.sort_values(by=['Year', 'WAR'], ascending=[True, False])
    team_bat = team_bat.sort_values(by=['Year', 'WAR'], ascending=[True, False])
    
    # (1) 개별 파일 저장
    team_pit.to_csv(f'{team}_2020_2025_투수.csv', index=False, encoding='utf-8-sig')
    team_bat.to_csv(f'{team}_2020_2025_타자.csv', index=False, encoding='utf-8-sig')
    
    # (2) 통합본 저장 (투수 상단, 타자 하단)
    combined = pd.concat([team_pit, team_bat], axis=0, ignore_index=True)
    combined.to_csv(f'{team}_2020_2025_통합본.csv', index=False, encoding='utf-8-sig')

print(f"✅ 요청하신 순서({', '.join(team_order)})대로 모든 팀 파일 생성이 완료되었습니다.")
# Out:
# ✅ 요청하신 순서(LG, 한화, SSG, 삼성, NC, KT, 롯데, KIA, 두산, 키움)대로 모든 팀 파일 생성이 완료되었습니다.

# %%
import pandas as pd

# 1. 파일 불러오기
pit_df = pd.read_csv('kbo_pitching_stats_by_season_1982-2025.csv')
bat_df = pd.read_csv('kbo_batting_stats_by_season_1982-2025.csv')

# 2. 연도 필터링 (2020~2025)
years = range(2020, 2026)
pit_f = pit_df[pit_df['Year'].isin(years)].copy()
bat_f = bat_df[bat_df['Year'].isin(years)].copy()

# 3. 요청하신 컬럼 순서 설정
pit_cols = ['Year', 'Team', 'Name', 'G', 'GS', 'GR', 'GF', 'IP', 'W', 'L', 'S', 'HD', 'SO', 'ERA', 'FIP', 'WHIP', 'WAR']
bat_cols = ['Year', 'Team', 'Name', 'G', 'PA', 'H', 'HR', 'RBI', 'R', 'SB', 'BB', 'SO', 'AVG', 'OBP', 'SLG', 'OPS', 'wRC+', 'oWAR', 'dWAR', 'WAR']

pit_selected = pit_f[pit_cols].copy()
bat_selected = bat_f[bat_cols].copy()

# 4. 팀명 통합 (SK -> SSG)
pit_selected['Team'] = pit_selected['Team'].replace('SK', 'SSG')
bat_selected['Team'] = bat_selected['Team'].replace('SK', 'SSG')

# 5. 2025년 순위대로 팀 순서 정렬
team_order = ['LG', '한화', 'SSG', '삼성', 'NC', 'KT', '롯데', 'KIA', '두산', '키움']

# 6. 팀 순서를 카테고리로 설정하여 정렬 준비
pit_selected['Team'] = pd.Categorical(pit_selected['Team'], categories=team_order, ordered=True)
bat_selected['Team'] = pd.Categorical(bat_selected['Team'], categories=team_order, ordered=True)

# 7. 정렬 (팀 순서 -> 연도순 -> WAR 높은순)
pit_final = pit_selected.sort_values(by=['Team', 'Year', 'WAR'], ascending=[True, True, False])
bat_final = bat_selected.sort_values(by=['Team', 'Year', 'WAR'], ascending=[True, True, False])

# 8. 최종 파일 2개로 나누어 저장
pit_final.to_csv('KBO_2020_2025_투수_전체통합.csv', index=False, encoding='utf-8-sig')
bat_final.to_csv('KBO_2020_2025_타자_전체통합.csv', index=False, encoding='utf-8-sig')

print("✅ 파일 생성 완료:")
print("1. KBO_2020_2025_투수_전체통합.csv (LG~키움 순)")
print("2. KBO_2020_2025_타자_전체통합.csv (LG~키움 순)")
# Out:
# ✅ 파일 생성 완료:
# 1. KBO_2020_2025_투수_전체통합.csv (LG~키움 순)
# 2. KBO_2020_2025_타자_전체통합.csv (LG~키움 순)
